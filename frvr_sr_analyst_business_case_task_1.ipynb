# %%
import pandas as pd 
import pandasql as ps
import os
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.display import display, HTML
display(HTML("<style>:root { --jp-notebook-max-width: 90% !important; }</style>"))
# Out:
# <style>:root { --jp-notebook-max-width: 90% !important; }</style>

# %% [markdown]
# # 1. SQL Query – Cohort Analysis & Retention Trends
#
# **Task:**
#
# - Write an SQL query to conduct a **Cohort Analysis** that tracks user retention **for 7 days, segmented by Acquisition Date**.
# - Extend beyond simple retention rates to **identify retention patterns by available dimensions**
#
# **Expected Output:**
#
# - a) SQL query
# - b) A table summarizing **Day 1-7 retention trends** per cohort.
# - c) Additional insights into retention patterns
#
# <aside>
# 📌 **Evaluation Focus:** SQL efficiency, correctness, cohort-based approach.
#
# </aside>

# %% [markdown]
# # Load Data

# %%
## Load dataset (Specify file name)
target_dir = 'data'
target_file = 'frvr-businesscase-dataset-3-.csv'
target_file_path = os.path.join(target_dir, target_file)

## Load dataset
frvr_user_events_raw = pd.read_csv(target_file_path, delimiter = ',')

## Drop duplicates
frvr_user_events_raw = frvr_user_events_raw.drop_duplicates()


## Read first 3 rows
frvr_user_events_raw.head(3)

# Add useful new columns
frvr_user_events_raw['acquisition_date'] = pd.to_datetime(frvr_user_events_raw['acquisition_date'])
frvr_user_events_raw['date'] = pd.to_datetime(frvr_user_events_raw['date'])
frvr_user_events_raw['days_since_acquisition'] = (frvr_user_events_raw['date'] - frvr_user_events_raw['acquisition_date']).dt.days

# %% [markdown]
# #### a) SQL Query

# %%
query = """
with frvr_users_retained_raw as (
    select 
          acquisition_date
        , date as event_date
        , julianday(date) - julianday(acquisition_date) as days_since_acquisition
        , count(distinct user_id) as users
    from frvr_user_events_raw
    group by 1,2,3 order by 1 asc
),
frvr_users_retained_formatted as (
    select 
          acquisition_date
        , cast(sum(case when days_since_acquisition = 0 then users end) as real) as users_acquired
        , sum(case when days_since_acquisition = 1 then users end) as users_retained_d1
        , sum(case when days_since_acquisition = 2 then users end) as users_retained_d2
        , sum(case when days_since_acquisition = 3 then users end) as users_retained_d3
        , sum(case when days_since_acquisition = 4 then users end) as users_retained_d4
        , sum(case when days_since_acquisition = 5 then users end) as users_retained_d5
        , sum(case when days_since_acquisition = 6 then users end) as users_retained_d6
        , sum(case when days_since_acquisition = 7 then users end) as users_retained_d7
    from frvr_users_retained_raw
    group by 1 
    order by 1 asc
),
frvr_users_retained_final as (
    select
          acquisition_date as "Acquisition Date"
        , users_acquired as "Users Acquired"
        , round(users_retained_d1 / users_acquired,3) as 'D1'
        , round(users_retained_d2 / users_acquired,3) as 'D2'
        , round(users_retained_d3 / users_acquired,3) as 'D3'
        , round(users_retained_d4 / users_acquired,3) as 'D4'
        , round(users_retained_d5 / users_acquired,3) as 'D5'
        , round(users_retained_d6 / users_acquired,3) as 'D6'
        , round(users_retained_d7 / users_acquired,3) as 'D7'
    from frvr_users_retained_formatted
    group by 1
    order by 1 asc
)
select * from frvr_users_retained_final
    """

result = ps.sqldf(query, locals())

#result = result.replace(np.nan, '-', regex=True)

result.head(5)
# Out:
#              Acquisition Date  Users Acquired     D1     D2     D3     D4  \
# 0  2022-10-07 00:00:00.000000          6160.0  0.149  0.112  0.091  0.074
# 1  2022-10-08 00:00:00.000000          5788.0  0.161  0.109  0.084  0.071
# 2  2022-10-09 00:00:00.000000          6158.0  0.151  0.093  0.086  0.068
# 3  2022-10-10 00:00:00.000000          6560.0  0.151  0.103  0.098  0.073
# 4  2022-10-11 00:00:00.000000          4872.0  0.154  0.101  0.083  0.064
#
#       D5     D6     D7
# 0  0.068  0.057  0.054
# 1  0.065  0.064  0.055
# 2  0.065  0.053  0.058
# 3  0.062  0.061  0.055
# 4  0.063  0.053  0.038

# %% [markdown]
# #### b) Summary Table: Day 1-7 retention trends per cohort

# %%
# Target columns for pct formatting
day_cols = ['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7']


# Format result (Number formatting, conditional formatting & Centering data)
styled_result = result.style \
        .format({
        **{col: "{:.1%}" for col in day_cols},           # Format D1–D7 as percentages
        'Users Acquired': "{:,.0f}"                      # Format with commas, no decimals
    }) \
    .background_gradient(subset=day_cols, cmap='Greens', vmin=0.02, vmax=0.165) \
    .highlight_null(color='white') \
    .set_properties(**{'text-align': 'center'})


styled_result
# Out:
# <style type="text/css">
# #T_c7120_row0_col0, #T_c7120_row0_col1, #T_c7120_row1_col0, #T_c7120_row1_col1, #T_c7120_row2_col0, #T_c7120_row2_col1, #T_c7120_row3_col0, #T_c7120_row3_col1, #T_c7120_row4_col0, #T_c7120_row4_col1, #T_c7120_row5_col0, #T_c7120_row5_col1, #T_c7120_row6_col0, #T_c7120_row6_col1, #T_c7120_row7_col0, #T_c7120_row7_col1, #T_c7120_row8_col0, #T_c7120_row8_col1, #T_c7120_row9_col0, #T_c7120_row9_col1, #T_c7120_row10_col0, #T_c7120_row10_col1, #T_c7120_row11_col0, #T_c7120_row11_col1, #T_c7120_row12_col0, #T_c7120_row12_col1, #T_c7120_row13_col0, #T_c7120_row13_col1, #T_c7120_row14_col0, #T_c7120_row14_col1 {
#   text-align: center;
# }
# #T_c7120_row0_col2 {
#   background-color: #00682a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row0_col3 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row0_col4 {
#   background-color: #78c679;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row0_col5 {
#   background-color: #a2d99c;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row0_col6, #T_c7120_row2_col5, #T_c7120_row5_col5 {
#   background-color: #afdfa8;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row0_col7 {
#   background-color: #c6e8bf;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row0_col8 {
#   background-color: #cbeac4;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row1_col2 {
#   background-color: #004d1f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row1_col3 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row1_col4 {
#   background-color: #8ace88;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row1_col5, #T_c7120_row9_col3 {
#   background-color: #a8dca2;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row1_col6, #T_c7120_row2_col6, #T_c7120_row10_col4 {
#   background-color: #b5e1ae;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row1_col7, #T_c7120_row4_col5 {
#   background-color: #b7e2b1;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row1_col8, #T_c7120_row3_col8, #T_c7120_row10_col5 {
#   background-color: #caeac3;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row2_col2, #T_c7120_row3_col2 {
#   background-color: #006328;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row2_col3 {
#   background-color: #73c476;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row2_col4 {
#   background-color: #84cc83;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row2_col7, #T_c7120_row4_col7 {
#   background-color: #ccebc6;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row2_col8, #T_c7120_row5_col6, #T_c7120_row6_col5, #T_c7120_row9_col4 {
#   background-color: #c3e7bc;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row3_col3, #T_c7120_row5_col3 {
#   background-color: #56b567;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row3_col4 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row3_col5, #T_c7120_row8_col3 {
#   background-color: #a4da9e;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row3_col6, #T_c7120_row7_col4 {
#   background-color: #bbe4b4;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row3_col7 {
#   background-color: #bde5b6;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row4_col2 {
#   background-color: #005c25;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row4_col3 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row4_col4, #T_c7120_row7_col3 {
#   background-color: #8bcf89;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row4_col6 {
#   background-color: #bae3b3;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row4_col8, #T_c7120_row7_col6 {
#   background-color: #e5f5e1;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row5_col2 {
#   background-color: #006027;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row5_col4, #T_c7120_row11_col4 {
#   background-color: #9bd696;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row5_col7, #T_c7120_row5_col8 {
#   background-color: #e2f4dd;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row6_col2 {
#   background-color: #016e2d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row6_col3 {
#   background-color: #7ac77b;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row6_col4 {
#   background-color: #a7dba0;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row6_col6 {
#   background-color: #dff3da;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row6_col7, #T_c7120_row8_col6 {
#   background-color: #e7f6e3;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row6_col8 {
#   background-color: #eff9eb;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row7_col2 {
#   background-color: #1d8640;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row7_col5 {
#   background-color: #daf0d4;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row7_col7, #T_c7120_row7_col8 {
#   background-color: #ecf8e8;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row8_col2 {
#   background-color: #248c46;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row8_col4 {
#   background-color: #d0edca;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row8_col5 {
#   background-color: #e0f3db;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row8_col7 {
#   background-color: #ebf7e7;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row8_col8, #T_c7120_row9_col7, #T_c7120_row9_col8, #T_c7120_row10_col6, #T_c7120_row10_col7, #T_c7120_row10_col8, #T_c7120_row11_col5, #T_c7120_row11_col6, #T_c7120_row11_col7, #T_c7120_row11_col8, #T_c7120_row12_col4, #T_c7120_row12_col5, #T_c7120_row12_col6, #T_c7120_row12_col7, #T_c7120_row12_col8, #T_c7120_row13_col3, #T_c7120_row13_col4, #T_c7120_row13_col5, #T_c7120_row13_col6, #T_c7120_row13_col7, #T_c7120_row13_col8, #T_c7120_row14_col2, #T_c7120_row14_col3, #T_c7120_row14_col4, #T_c7120_row14_col5, #T_c7120_row14_col6, #T_c7120_row14_col7, #T_c7120_row14_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   text-align: center;
# }
# #T_c7120_row9_col2 {
#   background-color: #278f48;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row9_col5 {
#   background-color: #ddf2d8;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row9_col6 {
#   background-color: #e4f5df;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row10_col2 {
#   background-color: #2b934b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row10_col3 {
#   background-color: #91d28e;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row11_col2 {
#   background-color: #077331;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row11_col3 {
#   background-color: #7fc97f;
#   color: #000000;
#   text-align: center;
# }
# #T_c7120_row12_col2, #T_c7120_row13_col2 {
#   background-color: #067230;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_c7120_row12_col3 {
#   background-color: #6dc072;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_c7120">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7120_level0_col0" class="col_heading level0 col0" >Acquisition Date</th>
#       <th id="T_c7120_level0_col1" class="col_heading level0 col1" >Users Acquired</th>
#       <th id="T_c7120_level0_col2" class="col_heading level0 col2" >D1</th>
#       <th id="T_c7120_level0_col3" class="col_heading level0 col3" >D2</th>
#       <th id="T_c7120_level0_col4" class="col_heading level0 col4" >D3</th>
#       <th id="T_c7120_level0_col5" class="col_heading level0 col5" >D4</th>
#       <th id="T_c7120_level0_col6" class="col_heading level0 col6" >D5</th>
#       <th id="T_c7120_level0_col7" class="col_heading level0 col7" >D6</th>
#       <th id="T_c7120_level0_col8" class="col_heading level0 col8" >D7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7120_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7120_row0_col0" class="data row0 col0" >2022-10-07 00:00:00.000000</td>
#       <td id="T_c7120_row0_col1" class="data row0 col1" >6,160</td>
#       <td id="T_c7120_row0_col2" class="data row0 col2" >14.9%</td>
#       <td id="T_c7120_row0_col3" class="data row0 col3" >11.2%</td>
#       <t

# %% [markdown]
# #### c) Additional Insights
#
# - We see a noticeable decrease in D1 Retention for users acquired between October 14th and October 17th
#
#
# - Below we calculate the average retention rate curves between 'control_group' and 'test_group' of the experiment
# - Although the method is imperfect (it's not a weighted based on the size of the cohort (users)) it is useful for quick observations.
# - Generally the retetention curves behave identical, with one exception:
# - There is an increase in retention for the test_group between day 8 - 12. This is surprising and should be investigated further!

# %% [markdown]
# ##### % Avg. Retention Rate: Control vs Test Group

# %%
retention_rate = frvr_user_events_raw.groupby(['acquisition_date','days_since_acquisition','ab_group'])['user_id'].nunique().reset_index()

#Rename column (user_id to users)
retention_rate = retention_rate.rename(columns={'user_id':'users'}) 

# Create new column which corresponds to initial users within each cohort (users at day 0)
retention_rate['users_acquired'] =  retention_rate.sort_values(['acquisition_date', 'days_since_acquisition']).groupby(['acquisition_date','ab_group'])['users'].transform('first')

# Create new column (users_retained)
retention_rate['users_retained'] =  retention_rate['users'] / retention_rate['users_acquired']

# Exclude D0
retention_rate = retention_rate[retention_rate['days_since_acquisition'] >= 1]  

# Get average retention_rate across all acquisition_date cohorts
retention_rate = retention_rate.groupby(['days_since_acquisition','ab_group'])['users_retained'].mean().reset_index()

# Pivot data to prepare for visualisation
retention_rate = retention_rate.pivot(index='days_since_acquisition', columns = 'ab_group', values = 'users_retained')


#sns.lineplot(retention_rate)
retention_rate.plot()
# Out:
# <Axes: xlabel='days_since_acquisition'>
